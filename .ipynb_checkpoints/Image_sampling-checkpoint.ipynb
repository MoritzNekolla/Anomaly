# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import math
import random

import torch
from Image_Sampler import Sampler

# %% [markdown]
# # Sampling Section

# %%
# sampler = Sampler(s_width=100, s_height=100, cam_height=4, cam_zoom=50, cam_rotation=-18)

# %%
sampler = Sampler(s_width=512, s_height=512, cam_height=4, cam_zoom=50, cam_rotation=-18)

# %%
sampler.show_Example(random_spawn=True)

# %%
image = sampler.sample()

# %%
plt.imshow(image)
plt.axis("off")
plt.savefig("sample.png")

# %%
image[250:310,200:350,:] = 0.0
plt.imshow(image)
plt.axis("off")
plt.savefig("sample_noisy.png")

# %%
errormap = np.zeros((512,512,1))
errormap[250:310,200:350,:] = 0.9
plt.axis("off")
plt.imshow(errormap, cmap="gray")
plt.savefig("error_map.png")

# %%
sampler.collect_Samples(sample_size=70)
# Out:
# finished world! 10
# finished world! 10
# finished world! 10
# finished world! 10
# finished world! 10
# finished world! 10
# finished world! 10
# Finished | Collected: 70 samples.

# %%
images = sampler.sample_Ride(world_model="Town01_Opt", num_of_snaps=50, tick_rate=5)

# %% [markdown]
# # Loading Section

# %%
images = Sampler.load_Images("/disk/vanishing_data/is789/anomaly_samples/Samples_2022-05-16_01:30:25/")
# Out:
# Loaded 10 images | width = 512, height = 512, channels = 3

# %%
images = images[:,:,:,:3]

# %%
images[0].shape
# Out:
# (512, 512, 3)

# %%
paths = Sampler.get_image_paths("/disk/vanishing_data/is789/anomaly_samples/Samples_2022-05-16_01:26:07/")

# %%
for x in range(9):
    plt.imshow(images[x])
    plt.show()

# %%
Sampler.sample_from_Set(images)
# Out:
# width = 512, height = 512, channels = 3

# %%
def convert_pic_to_row(pic):
    output = []
    for col in(pic):
        temp = []
        for x in range(len(col)):
            row = col[x]
            temp = np.concatenate((temp,row), axis=None)
        output = np.concatenate((output,temp), axis=None)

    result = np.array(output)
    result = result.astype(int)
    return result

# %%
import csv

f = open("./test.csv", 'w')

with f:

    writer = csv.writer(f)
    
    for image in images:
        image = convert_pic_to_row(image)
        writer.writerow(image)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [45], in <cell line: 5>()
#       7 writer = csv.writer(f)
#       9 for image in images:
# ---> 10     image = convert_pic_to_row(image)
#      11     writer.writerow(image)
#
# Input In [43], in convert_pic_to_row(pic)
#       5     for x in range(len(col)):
#       6         row = col[x]
# ----> 7         temp = np.concatenate((temp,row), axis=None)
#       8     output = np.concatenate((output,temp), axis=None)
#      10 result = np.array(output)
#
# File <__array_function__ internals>:180, in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
test = convert_pic_to_row(images[0])
test
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
import cv2

# %%
k = (images[0] * 255).astype("int")

# %%
import PIL

# %%
cv2.imwrite("test.png", k)
# Out:
# True

# %%
img = cv2.imread("test.png")
# Out:
# numpy.ndarray

# %%
def load_img_csv(path): 
    f = open("./test.csv", 'r')

    loaded_state = []
    result = []


    with f:

        reader = csv.reader(f)

        for row in reader:
            temp = []
            for e in row:
                temp.append(e)
            loaded_state.append(temp)

    return loaded_state

# %%
kappa = load_img_csv("s")
